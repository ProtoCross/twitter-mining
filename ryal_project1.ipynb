# %% [markdown]
# # Twitter Project
#
# ## Author: Joshua Ryal
#
# ### Description: Finding differences in word preference and sentiment between 3 professional Smash Brothers players (Duck, Leffen, and Mew2King)

# %% [markdown]
# ## Duck's Tweets

# %%
import pickle

#Load pickle
with open('duck.pkl', 'rb') as x:
    duck = pickle.load(x)

#Print tweets
for x in duck:
    print(x.text)
# Out:
# @TeeAyEye @overshot_nair That clip should've ended with a wobble lmao
# @JWonggg @KBradJStorm https://t.co/I8y58W9FAI
# @Violent_Lee @HugS86 @serinide I was tricked into thinking I hated salad for 20 years because the average "salad" w… https://t.co/PhaXctbcl0
# @HugS86 @serinide It's what happens when your only exposure to vegetables is half cooked boiled ones
# @tsumugii_ @TL343 @Syphichan @Zealous5000 @ShipSSBM &gt;.&gt;
# Roy feels so much better than chrom in smush
#
# You can actually interact with people offstage instead of watching them recover
# RT @Savestate: A little showcase of the (literally) game-breaking glitch I found and @Absolome helped me lab out. GHOST ARROW. If you chain…
# @PvtBussy_1989 It's honestly normal to not reply now since online applications are so popular, but it feels rude/sh… https://t.co/ylGLyCeR99
# @C9Mang0 actually campaigning for summit has me both terrified and intrigued
# I nominated @C9Mang0 for @BTSsmash #SmashSummit
# ...

# %% [markdown]
# ## Leffen's tweets

# %%
import pickle

#Load pickle
with open('leffen.pkl', 'rb') as x:
    leffen = pickle.load(x)

#Print tweets
for x in leffen:
    print(x.text)
# Out:
# Live!
# Gonna play some Ultimate, maybe some more Battle royale games later :)
# https://t.co/8NOSC7r3wT
# tetris 99 ruined my life ama
# Battle Royale Tetris
# Peak of humanity right here
# going to be playing all the shit announced in the Nintendo Direct… https://t.co/xtaCvhZEAn
# twitch prime
# (he has one from smash 4 but idgaf like my tweet)
# Even fucking Nintendo knows charizard is bottom tier in Ultimate https://t.co/eYnMIF0FuA
# best thing  since salem didnt make it to summit
# actually
# this confirms no sora in smash
# LETSFUCKINGGO
# BOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Fire Emblen : Three frames
# NINTENDO DIRECT HYPE
# https://t.co/8NOSC7r3wT
# streaming!
# Nintendo Direct in 5 hours, watching that + predictions
# First summit Vote today! Discussing who I think… https://t.co/GTlXXlQNtt
# @SkyWilliams i noticed this too on my flight
# literally felt like a gut punch
# ...

# %% [markdown]
# ## M2K's Tweets

# %%
import pickle

#Load pickle
with open('m2k.pkl', 'rb') as x:
    m2k = pickle.load(x)

#Print tweets
for x in m2k:
    print(x.text)
# Out:
# @julie_trivelli King
# https://t.co/FYbrBoZIAi - going live in few min
# My first tourney was 14 years ago, Feb 14 2005
# @U_ris2 Where's the hurtbox? Why is it 4 different colors?
# @Noisert How? Elaborate?
# RT @FictionIRL: I wish people would be more honest about people playing bad/rust. I almost never see acknowledgement of such things. People…
# When/how should I use upsmash as Wolf?
# @PG_Plup Everyone get ready to make sick levels for us!
# @FictionIRL I say it all the time for others but i dont think they do it back for me very often
# RT @Mkleosb: Stream is live
# @MVG_Mew2King is gonna be here soon! Come hang out https://t.co/NdS8cnJLdg
# I'm hyped for Super Mario Maker 2!  Mariomaker is me and @PG_Plup 's favorite Wii U game afaik. Can't wait to play/stream it all the time!
# @Mkleosb Friendlies*
# https://t.co/FYbrBoZIAi - friendles with @Mkleosb and Nintendo Direct afterwards
# ...

# %% [markdown]
# ## Duck Word Cloud

# %%
import matplotlib.pyplot as plt
import pickle
from wordcloud import WordCloud

#Load pickle
with open('duck.pkl', 'rb') as f:
    tweets = pickle.load(f)

#Filter out urls
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
for x in lexemes:
    if "https" in x:
        lexemes.remove(x)
#Change to string for compatability with word cloud
text = ' '. join(lexemes)

#Generate word cloud
wordcloud = WordCloud(max_font_size = 40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Leffen Word Cloud

# %%
import matplotlib.pyplot as plt
import pickle
from wordcloud import WordCloud

##Load pickle
with open('leffen.pkl', 'rb') as f:
    tweets = pickle.load(f)

#Filter out urls
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
for x in lexemes:
    if "https" in x:
        lexemes.remove(x)
#Change to string for compatability with word cloud
text = ' '. join(lexemes)

#Generate word cloud
wordcloud = WordCloud(max_font_size = 40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## M2K Word Cloud

# %%
import matplotlib.pyplot as plt
import pickle
from wordcloud import WordCloud

#Load pickle
with open('m2k.pkl', 'rb') as f:
    tweets = pickle.load(f)
 
#Filter out urls
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
for x in lexemes:
    if "https" in x:
        lexemes.remove(x)
#Change to string for compatability with word cloud
text = ' '. join(lexemes)

#Generate word cloud
wordcloud = WordCloud(max_font_size = 40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Duck Sentiment Analysis

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('duck.pkl', 'rb') as x:
    duck = pickle.load(x)

def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neg_y = [s['neg'] for s in sents]
    comp_z = [s['compound'] for s in sents]
    return pos_x, neg_y, comp_z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(duck)

ax.scatter(rbx, rby, rbz, c = 'r', marker = 'o')
ax.set_xlabel('Positive')
ax.set_ylabel('Negative')
ax.set_zlabel('Compound')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Josh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Leffen Sentiment Analysis

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('leffen.pkl', 'rb') as x:
    leffen = pickle.load(x)

def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neg_y = [s['neg'] for s in sents]
    comp_z = [s['compound'] for s in sents]
    return pos_x, neg_y, comp_z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(leffen)

ax.scatter(rbx, rby, rbz, c = 'r', marker = 'o')
ax.set_xlabel('Positive')
ax.set_ylabel('Negative')
ax.set_zlabel('Compound')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Josh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## M2K Sentiment Analysis

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('m2k.pkl', 'rb') as x:
    m2k = pickle.load(x)

def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neg_y = [s['neg'] for s in sents]
    comp_z = [s['compound'] for s in sents]
    return pos_x, neg_y, comp_z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(m2k)

ax.scatter(rbx, rby, rbz, c = 'r', marker = 'o')
ax.set_xlabel('Positive')
ax.set_ylabel('Negative')
ax.set_zlabel('Compound')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Josh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Conclusions
#
# ### Duck
# Duck frequently uses "RT" and "lol" in his tweets. He also commonly tags the users spotdodge_shine and HugS86 when he tweets. The sentiment analysis shows a decent spread in word sentiment along the neutral-positive scale.
#
# ### Leffen
# Leffen frequently uses "Melee" and "Ultimate" in his tweets. "Young Link" is used a lot as it is the character he's currently learning in Ultimate. The sentiment analysis shows a spread along the negative axis.
#
# ### M2K
# "ComeToFrostbite" is heavily used in M2K's past 250 tweets. This is likely due to him being one of the major faces attending the upcoming tournament. The sentiment analysis is mostly clustered in the positive axis.
